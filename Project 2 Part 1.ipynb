# %% [markdown]
# # IS 362 - Project 2 - Part 1
# ### Data: Death Rates NYC

# %% [markdown]
# ###### Your task is to:
# 1.Choose any three of the “wide” datasets identified in the Week 5 Discussion items. (You may use your own dataset; please don’t use my Sample Post dataset, since that was used in your Project 1 assignment!) For each of the three chosen datasets:
# - Create a .CSV file (or optionally, a MySQL database!) that includes all of the information included in the dataset. You’re encouraged to use a “wide” structure similar to how the information appears in the discussion item, so that you can practice tidying and transformations as described below.
# - Read the information from your .CSV file into Python, and use pandas as needed to tidy and transform your data. [Most of your grade will be based on this step!]
# - Perform the analysis requested in the discussion item.
# - Your code should be in an Jupyter Notebook, posted to your GitHub repository, and should include narrative descriptions of your data cleanup work, analysis, and conclusions.
#
# 2.Please include the URL for the Jupyter Notebook in your homework submission, for each of the three chosen datasets. You may create a single Jupyter Notebook, or three separate notebooks.

# %% [markdown]
# #### 1. Import pandas, read data from csv file and display all the data here.

# %%
import pandas as pd
import numpy as np

# %%
death_rates = pd.read_csv('Death_Rates_NYC.csv')
death_rates
# Out:
#      Year                                      Leading Cause Sex  \
# 0    2014                        Diabetes Mellitus (E10-E14)   F
# 1    2011          Cerebrovascular Disease (Stroke: I60-I69)   M
# 2    2008              Malignant Neoplasms (Cancer: C00-C97)   M
# 3    2010              Malignant Neoplasms (Cancer: C00-C97)   F
# 4    2012          Cerebrovascular Disease (Stroke: I60-I69)   M
# 5    2007  Mental and Behavioral Disorders due to Use of ...   M
# 6    2011                                   All Other Causes   F
# 7    2007       Chronic Lower Respiratory Diseases (J40-J47)   F
# 8    2012  Essential Hypertension and Renal Diseases (I10...   F
# 9    2009     Diseases of Heart (I00-I09, I11, I13, I20-I51)   M
# 10   2011       Chronic Lower Respiratory Diseases (J40-J47)   M
# 11   2008          Cerebrovascular Disease (Stroke: I60-I69)   F
# 12   2013     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# ...

# %% [markdown]
# #### 2. There is couple issues exist in this above data.
# - There is dot's in multiple places of the data which should be N/A or Null.
# - The data is not sorted by any columns.

# %% [markdown]
# Now, let's change the dot's to null and sort the data by Year and Leading Cause and use pandas as needed to tidy and transform your data.

# %% [markdown]
# death_rates = death_rates.replace(to_replace='.', value='null')
# death_rates.sort_values(by=['Year', 'Leading Cause'])

# %% [markdown]
# #### 3. Let's filter the data and only show Females of White Non-Hispanic race ethnicity.

# %%
death_rates[(death_rates['Sex']=='F') & 
            (death_rates['Race Ethnicity'] == 'White Non-Hispanic')].sort_values(by = ['Year' , 'Deaths'])
# Out:
#      Year                                      Leading Cause Sex  \
# 181  2007  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 234  2007                                   All Other Causes   F
# 230  2008                                   All Other Causes   F
# 38   2008                        Diabetes Mellitus (E10-E14)   F
# 190  2009              Malignant Neoplasms (Cancer: C00-C97)   F
# 133  2010  Essential Hypertension and Renal Diseases (I10...   F
# 224  2010       Chronic Lower Respiratory Diseases (J40-J47)   F
# 119  2010     Diseases of Heart (I00-I09, I11, I13, I20-I51)   F
# 165  2011  Essential Hypertension and Renal Diseases (I10...   F
# 195  2011              Malignant Neoplasms (Cancer: C00-C97)   F
# 27   2011  Mental and Behavioral Disorders due to Acciden...   F
# 285  2012  Accidents Except Drug Posioning (V01-X39, X43,...   F
# 115  2012  Essential Hypertension and Renal Diseases (I10...   F
# ...

# %% [markdown]
# #### 4. Let's now filter data by grouping by Race Ethnicity and sort the data by Race Ethnicity and Leading Cause.

# %%
groupbyrace= (death_rates.sort_values(by=['Race Ethnicity','Leading Cause'])
.set_index(['Race Ethnicity','Leading Cause']))
groupbyrace
# Out:
#                                                                                Year  \
# Race Ethnicity             Leading Cause
# Asian and Pacific Islander Accidents Except Drug Posioning (V01-X39, X43, ...  2007
#                            Accidents Except Drug Posioning (V01-X39, X43, ...  2011
#                            Accidents Except Drug Posioning (V01-X39, X43, ...  2010
#                            All Other Causes                                    2009
#                            All Other Causes                                    2014
#                            All Other Causes                                    2010
#                            All Other Causes                                    2010
#                            All Other Causes                                    2012
#                            All Other Causes                                    2009
#                            Cerebrovascular Disease (Stroke: I60-I69)           2011
# ...
